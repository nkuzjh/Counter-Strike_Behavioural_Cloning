# %%
import numpy as np
import matplotlib.pyplot as plt
import PIL

# %%
dm_test_expert_1 = np.load('D:/projects/data_collecting/csgo/debug/dm_test_expert_1.npy', allow_pickle=True)

# %%
dm_test_expert_1.shape
# Out:
# (1000, 2)

# %%
dm_test_expert_1[0].shape
# Out:
# (2,)

# %%
dm_test_expert_1[0][0].shape
# Out:
# (150, 280, 3)

# %%
dm_test_expert_1[0][1]
# Out:
# {'obs_mode': 0,
#  'gsi_team': 'CT',
#  'gsi_health': 100,
#  'gsi_kills': 4,
#  'gsi_deaths': 7,
#  'gsi_weapons': {'weapon_0': {'name': 'weapon_knife',
#    'paintkit': 'default',
#    'type': 'Knife',
#    'state': 'holstered'},
#   'weapon_1': {'name': 'weapon_hkp2000',
#    'paintkit': 'default',
#    'type': 'Pistol',
#    'ammo_clip': 13,
#    'ammo_clip_max': 13,
#    'ammo_reserve': 52,
#    'state': 'active'}},
#  'found_active': True,
#  'gsi_weap_active': {'name': 'weapon_hkp2000',
#   'paintkit': 'default',
#   'type': 'Pistol',
#   'ammo_clip': 13,
#   'ammo_clip_max': 13,
#   'ammo_reserve': 52,
#   'state': 'active'},
#  'gsi_ammo': 13,
#  'obs_health': 0,
#  'obs_fov': 0,
#  'obs_scope': 0,
#  'localpos1': 0,
#  'localpos2': 0,
#  'localpos3': 0,
#  'height': 0,
#  'vel_1': 0,
#  'vel_2': 0,
#  'vel_3': 0,
#  'vel_mag': 0.0,
#  'vel_theta_abs': 0,
#  'itemdef': 0,
#  'ammo_active': 0,
#  'tp_wasd': [],
#  'tp_lclick': 1}

# %%
plt.figure()

for i in range(0,100,10):
    img = PIL.Image.fromarray(dm_test_expert_1[i][0])
    plt.imshow(img)
